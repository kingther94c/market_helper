# %% [markdown]
# # Regime Engine v2 Calibration Questions
#
# Observation: The static HTML report is `data/artifacts/regime_detection/calibration/regime_v2_calibration_report.html` and the daily calibration JSON is `data/artifacts/regime_detection/calibration/regime_v2_calibration_daily.json`.
#
# Question: Should the next iteration prioritize config-only threshold/weight changes, or deeper signal normalization changes?

# %% [markdown]
# ## Data Coverage
#
# Observation: Macro panel is available from 1920-02-18 to 2026-04-29 with 27706 rows; market panel is available from 1984-01-03 to 2026-05-08 with 11049 rows.
#
# Question: Should we require full-history market coverage before making any market_implied or risk-overlay calibration decision?

# %% [markdown]
# ## 2008-09 GFC
#
# Observation: 2008-09 GFC majority regime is Slowdown / Deflationary Slowdown + Stress Overlay; stress share 29%; disagreement share 69%; coverage macro/market/risk 100%/100%/100%; macro G/I -0.87/-0.20; market G/I -0.02/-0.24.
#
# Question: Does v2 show a deflationary slowdown/stress phase without needing risk to redefine the macro axes?

# %% [markdown]
# ## 2009-10 Recovery
#
# Observation: 2009-10 Recovery majority regime is Neutral/Mixed Growth / Neutral/Mixed Inflation; stress share 0%; disagreement share 25%; coverage macro/market/risk 100%/100%/100%; macro G/I -0.12/-0.31; market G/I 0.16/0.08.
#
# Question: Should early-cycle recovery be allowed to appear as Reflation before macro growth fully confirms?

# %% [markdown]
# ## 2011 Euro Debt / US Downgrade
#
# Observation: 2011 Euro Debt / US Downgrade majority regime is Neutral/Mixed Growth / Neutral/Mixed Inflation; stress share 0%; disagreement share 24%; coverage macro/market/risk 100%/100%/100%; macro G/I 0.34/-0.20; market G/I -0.22/-0.12.
#
# Question: Is disagreement here useful context rather than a reason to force consensus?

# %% [markdown]
# ## 2014-16 Oil Collapse
#
# Observation: 2014-16 Oil Collapse majority regime is Neutral/Mixed Growth / Down Inflation; stress share 2%; disagreement share 19%; coverage macro/market/risk 100%/100%/100%; macro G/I 0.17/-0.50; market G/I -0.18/-0.23.
#
# Question: Should collapsing oil dominate market-implied inflation, or should core inflation persistence dampen it?

# %% [markdown]
# ## 2017 Soft Landing
#
# Observation: 2017 Soft Landing majority regime is Goldilocks / Expansion; stress share 0%; disagreement share 28%; coverage macro/market/risk 100%/100%/100%; macro G/I 0.17/-0.40; market G/I 0.19/0.16.
#
# Question: Does the engine distinguish healthy expansion from overheating inflation pressure?

# %% [markdown]
# ## 2018 Q4 Selloff
#
# Observation: 2018 Q4 Selloff majority regime is Slowdown / Deflationary Slowdown; stress share 9%; disagreement share 0%; coverage macro/market/risk 100%/100%/100%; macro G/I 0.12/-0.13; market G/I -0.36/-0.36.
#
# Question: Should this be treated as a market-implied warning that does not require immediate macro confirmation?

# %% [markdown]
# ## 2020 COVID Shock
#
# Observation: 2020 COVID Shock majority regime is Slowdown / Deflationary Slowdown + Stress Overlay; stress share 44%; disagreement share 0%; coverage macro/market/risk 100%/100%/100%; macro G/I -0.36/-0.39; market G/I -0.36/-0.51.
#
# Question: Is macro lag acceptable here, or should the macro fast bucket become more reactive?

# %% [markdown]
# ## 2020 H2-2021 Reopening
#
# Observation: 2020 H2-2021 Reopening majority regime is Reflation; stress share 0%; disagreement share 36%; coverage macro/market/risk 100%/100%/100%; macro G/I 0.13/-0.15; market G/I 0.19/0.26.
#
# Question: Does the inflation axis rise early enough without turning every expansion into Reflation?

# %% [markdown]
# ## 2022 Inflation Shock / Tightening
#
# Observation: 2022 Inflation Shock / Tightening majority regime is Neutral/Mixed Growth / Neutral/Mixed Inflation; stress share 0%; disagreement share 56%; coverage macro/market/risk 100%/100%/100%; macro G/I 0.30/0.54; market G/I -0.17/-0.05.
#
# Question: Should realized CPI/PCE persistence carry more weight than commodity rollover in late 2022?

# %% [markdown]
# ## 2023-24 Disinflation / Soft Landing
#
# Observation: 2023-24 Disinflation / Soft Landing majority regime is Neutral/Mixed Growth / Neutral/Mixed Inflation; stress share 0%; disagreement share 38%; coverage macro/market/risk 100%/100%/100%; macro G/I -0.02/0.50; market G/I 0.07/-0.08.
#
# Question: Should the base label lean Goldilocks when inflation is easing but still above normal?

# %% [markdown]
# ## 2025 April Liberation Day Tariff Shock
#
# Observation: 2025 April Liberation Day Tariff Shock majority regime is Down Growth / Neutral/Mixed Inflation; stress share 11%; disagreement share 0%; coverage macro/market/risk 100%/100%/100%; macro G/I 0.05/0.17; market G/I -0.31/-0.11.
#
# Question: Should this be classified as meaningful short-lived market-implied dislocation, false alarm, or correct stagflation warning?

# %% [markdown]
# ## Recommended Next Config Pass
#
# Observation: Prefer config-only changes first: thresholds, layer weights, market lookbacks, and macro bucket weights.
#
# Question: Which recommendation should be implemented first in the next calibration iteration?
