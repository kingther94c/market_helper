# %% [markdown]
# # Regime Engine v2 Calibration Questions
#
# Observation: The static HTML report is `data/artifacts/regime_detection/calibration/regime_v2_calibration_report.html` and the daily calibration JSON is `data/artifacts/regime_detection/calibration/regime_v2_calibration_daily.json`.
#
# Question: Should the next iteration prioritize config-only threshold/weight changes, or deeper signal normalization changes?

# %% [markdown]
# ## Data Coverage
#
# Observation: Macro panel is available from 1920-02-18 to 2026-04-29 with 27706 rows; market panel is available from 1990-01-02 to 2026-05-05 with 9481 rows.
#
# Question: Should we require full-history market coverage before making any market_implied or risk-overlay calibration decision?

# %% [markdown]
# ## 2008-09 GFC
#
# Observation: 2008-09 GFC majority regime is Slowdown / Deflationary Slowdown + Stress Overlay; stress share 59%; disagreement share 57%; coverage macro/market/risk 100%/100%/100%; macro G/I -5.61/-1.19; market G/I -0.28/-1.01.
#
# Question: Does v2 show a deflationary slowdown/stress phase without needing risk to redefine the macro axes?

# %% [markdown]
# ## 2009-10 Recovery
#
# Observation: 2009-10 Recovery majority regime is Goldilocks / Expansion; stress share 0%; disagreement share 55%; coverage macro/market/risk 100%/100%/100%; macro G/I -0.66/-1.20; market G/I 0.43/0.10.
#
# Question: Should early-cycle recovery be allowed to appear as Reflation before macro growth fully confirms?

# %% [markdown]
# ## 2011 Euro Debt / US Downgrade
#
# Observation: 2011 Euro Debt / US Downgrade majority regime is Goldilocks / Expansion; stress share 19%; disagreement share 65%; coverage macro/market/risk 100%/100%/100%; macro G/I 2.74/-0.78; market G/I -0.56/-0.21.
#
# Question: Is disagreement here useful context rather than a reason to force consensus?

# %% [markdown]
# ## 2014-16 Oil Collapse
#
# Observation: 2014-16 Oil Collapse majority regime is Goldilocks / Expansion; stress share 34%; disagreement share 52%; coverage macro/market/risk 100%/100%/100%; macro G/I 1.53/-1.79; market G/I -0.51/-0.83.
#
# Question: Should collapsing oil dominate market-implied inflation, or should core inflation persistence dampen it?

# %% [markdown]
# ## 2017 Soft Landing
#
# Observation: 2017 Soft Landing majority regime is Goldilocks / Expansion; stress share 0%; disagreement share 50%; coverage macro/market/risk 100%/100%/100%; macro G/I 1.65/-1.39; market G/I 0.39/0.42.
#
# Question: Does the engine distinguish healthy expansion from overheating inflation pressure?

# %% [markdown]
# ## 2018 Q4 Selloff
#
# Observation: 2018 Q4 Selloff majority regime is Goldilocks / Expansion; stress share 50%; disagreement share 89%; coverage macro/market/risk 100%/100%/100%; macro G/I 2.41/-0.42; market G/I -1.39/-0.97.
#
# Question: Should this be treated as a market-implied warning that does not require immediate macro confirmation?

# %% [markdown]
# ## 2020 COVID Shock
#
# Observation: 2020 COVID Shock majority regime is Slowdown / Deflationary Slowdown + Stress Overlay; stress share 87%; disagreement share 51%; coverage macro/market/risk 100%/100%/100%; macro G/I -2.28/-1.44; market G/I -1.42/-2.12.
#
# Question: Is macro lag acceptable here, or should the macro fast bucket become more reactive?

# %% [markdown]
# ## 2020 H2-2021 Reopening
#
# Observation: 2020 H2-2021 Reopening majority regime is Reflation; stress share 0%; disagreement share 52%; coverage macro/market/risk 100%/100%/100%; macro G/I 2.34/0.17; market G/I 0.48/0.67.
#
# Question: Does the inflation axis rise early enough without turning every expansion into Reflation?

# %% [markdown]
# ## 2022 Inflation Shock / Tightening
#
# Observation: 2022 Inflation Shock / Tightening majority regime is Reflation; stress share 20%; disagreement share 79%; coverage macro/market/risk 100%/100%/100%; macro G/I 3.91/3.41; market G/I -0.61/0.06.
#
# Question: Should realized CPI/PCE persistence carry more weight than commodity rollover in late 2022?

# %% [markdown]
# ## 2023-24 Disinflation / Soft Landing
#
# Observation: 2023-24 Disinflation / Soft Landing majority regime is Goldilocks / Expansion; stress share 3%; disagreement share 40%; coverage macro/market/risk 100%/100%/100%; macro G/I 1.01/1.18; market G/I 0.24/-0.31.
#
# Question: Should the base label lean Goldilocks when inflation is easing but still above normal?

# %% [markdown]
# ## 2025 April Liberation Day Tariff Shock
#
# Observation: 2025 April Liberation Day Tariff Shock majority regime is Neutral/Mixed Growth / Neutral/Mixed Inflation; stress share 48%; disagreement share 84%; coverage macro/market/risk 100%/100%/100%; macro G/I 1.41/0.10; market G/I -1.10/-0.63.
#
# Question: Should this be classified as meaningful short-lived market-implied dislocation, false alarm, or correct stagflation warning?

# %% [markdown]
# ## Recommended Next Config Pass
#
# Observation: Review whether these high-disagreement windows are desirable dislocations: 2018 Q4 Selloff, 2022 Inflation Shock / Tightening, 2025 April Liberation Day Tariff Shock. Prefer config-only changes first: thresholds, layer weights, market lookbacks, and macro bucket weights.
#
# Question: Which recommendation should be implemented first in the next calibration iteration?
