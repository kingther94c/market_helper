# %% [markdown]
# # Regime Engine v2 Calibration Questions
#
# Observation: The static HTML report is `data/artifacts/regime_detection/calibration/regime_v2_calibration_report.html` and the daily calibration JSON is `data/artifacts/regime_detection/calibration/regime_v2_calibration_daily.json`.
#
# Question: Should the next iteration prioritize config-only threshold/weight changes, or deeper signal normalization changes?

# %% [markdown]
# ## Data Coverage
#
# Observation: Macro panel is available from 1920-02-18 to 2026-04-29 with 27706 rows; market panel is available from 2026-03-04 to 2026-05-04 with 44 rows.
#
# Question: Should we require full-history market coverage before making any market_implied or risk-overlay calibration decision?

# %% [markdown]
# ## 2008-09 GFC
#
# Observation: 2008-09 GFC majority regime is Stagflation-like; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I -5.61/2.27; market unavailable.
#
# Question: Does v2 show a deflationary slowdown/stress phase without needing risk to redefine the macro axes?

# %% [markdown]
# ## 2009-10 Recovery
#
# Observation: 2009-10 Recovery majority regime is Reflation; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I -0.66/2.05; market unavailable.
#
# Question: Should early-cycle recovery be allowed to appear as Reflation before macro growth fully confirms?

# %% [markdown]
# ## 2011 Euro Debt / US Downgrade
#
# Observation: 2011 Euro Debt / US Downgrade majority regime is Reflation; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I 2.74/2.28; market unavailable.
#
# Question: Is disagreement here useful context rather than a reason to force consensus?

# %% [markdown]
# ## 2014-16 Oil Collapse
#
# Observation: 2014-16 Oil Collapse majority regime is Reflation; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I 1.53/1.87; market unavailable.
#
# Question: Should collapsing oil dominate market-implied inflation, or should core inflation persistence dampen it?

# %% [markdown]
# ## 2017 Soft Landing
#
# Observation: 2017 Soft Landing majority regime is Reflation; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I 1.65/2.06; market unavailable.
#
# Question: Does the engine distinguish healthy expansion from overheating inflation pressure?

# %% [markdown]
# ## 2018 Q4 Selloff
#
# Observation: 2018 Q4 Selloff majority regime is Reflation; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I 2.41/2.42; market unavailable.
#
# Question: Should this be treated as a market-implied warning that does not require immediate macro confirmation?

# %% [markdown]
# ## 2020 COVID Shock
#
# Observation: 2020 COVID Shock majority regime is Reflation; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I -2.28/2.30; market unavailable.
#
# Question: Is macro lag acceptable here, or should the macro fast bucket become more reactive?

# %% [markdown]
# ## 2020 H2-2021 Reopening
#
# Observation: 2020 H2-2021 Reopening majority regime is Stagflation-like; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I 2.34/2.87; market unavailable.
#
# Question: Does the inflation axis rise early enough without turning every expansion into Reflation?

# %% [markdown]
# ## 2022 Inflation Shock / Tightening
#
# Observation: 2022 Inflation Shock / Tightening majority regime is Reflation; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I 3.91/4.44; market unavailable.
#
# Question: Should realized CPI/PCE persistence carry more weight than commodity rollover in late 2022?

# %% [markdown]
# ## 2023-24 Disinflation / Soft Landing
#
# Observation: 2023-24 Disinflation / Soft Landing majority regime is Reflation; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I 1.01/3.37; market unavailable.
#
# Question: Should the base label lean Goldilocks when inflation is easing but still above normal?

# %% [markdown]
# ## 2025 April Liberation Day Tariff Shock
#
# Observation: 2025 April Liberation Day Tariff Shock majority regime is Reflation; stress share 0%; disagreement share 0%; coverage macro/market/risk 100%/0%/0%; macro G/I 1.41/2.83; market unavailable.
#
# Question: Should this be classified as meaningful short-lived market-implied dislocation, false alarm, or correct stagflation warning?

# %% [markdown]
# ## Recommended Next Config Pass
#
# Observation: Market layer coverage is insufficient in at least one anchor; avoid market_implied calibration until full-history market data is present. Risk overlay coverage is incomplete in at least one anchor; stress-share conclusions are coverage-limited. Prefer config-only changes first: thresholds, layer weights, market lookbacks, and macro bucket weights.
#
# Question: Which recommendation should be implemented first in the next calibration iteration?
