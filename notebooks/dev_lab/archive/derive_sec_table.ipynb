# %% [markdown]
# # Derive Security Table
#
# This notebook is a live IBKR contract lookup tool built on `market_helper.providers.tws_ib_async`.
#
# Prerequisites:
# - Run it with the `py313` kernel.
# - Start TWS or IB Gateway locally.
# - Enable API access and confirm the host, port, and client ID match your local settings.
# - Each live notebook or script needs a unique `IB_CLIENT_ID`.
# - If the lookup is ambiguous, tighten `PRIMARY_EXCHANGE` or set `CONID` directly.

# %%
from pathlib import Path
import sys

project_root = Path.cwd().resolve()
while not (project_root / "market_helper").exists():
    if project_root.parent == project_root:
        raise RuntimeError("Could not find project root containing the market_helper package.")
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

SYMBOL = "XLK"
SEC_TYPE = "STK"
EXCHANGE = "SMART"
PRIMARY_EXCHANGE = "ARCA"
CURRENCY = "USD"
CONID = None
LOCAL_SYMBOL = None

IB_HOST = "127.0.0.1"
IB_PORT = 7497
IB_CLIENT_ID = 121
IB_ACCOUNT = ""

print(f"Project root: {project_root}")
print(
    "Lookup target: "
    f"symbol={SYMBOL}, sec_type={SEC_TYPE}, exchange={EXCHANGE}, "
    f"primary_exchange={PRIMARY_EXCHANGE}, currency={CURRENCY}, conid={CONID}"
)
print(f"IBKR connection: host={IB_HOST}, port={IB_PORT}, client_id={IB_CLIENT_ID}, account={IB_ACCOUNT or '<default>'}")
# Out:
# Project root: /Users/kelvin/git_projects/market_helper
# Lookup target: symbol=XLK, sec_type=STK, exchange=SMART, primary_exchange=ARCA, currency=USD, conid=None
# IBKR connection: host=127.0.0.1, port=7497, client_id=121, account=<default>

# %%
from pprint import pprint

from market_helper.providers.tws_ib_async import TwsIbAsyncClient

client = TwsIbAsyncClient(
    host=IB_HOST,
    port=IB_PORT,
    client_id=IB_CLIENT_ID,
    account=IB_ACCOUNT,
)

try:
    client.connect()
    security_info = client.require_security_info(
        symbol="DBMF",
        sec_type=SEC_TYPE,
        exchange=EXCHANGE,
        primary_exchange=PRIMARY_EXCHANGE,
        currency=CURRENCY,
        conid=CONID,
        local_symbol=LOCAL_SYMBOL,
    )
finally:
    client.disconnect()

pprint(security_info)
# Out:
# {'category': '',
#  'conId': 515416076,
#  'currency': 'USD',
#  'exchange': 'SMART',
#  'industry': '',
#  'liquidHours': '20260329:CLOSED;20260330:0930-20260330:1600;20260331:0930-20260331:1600;20260401:0930-20260401:1600;20260402:0930-20260402:1600',
#  'localSymbol': 'DBMF',
#  'longName': 'IMGP DBI MANAGED FUTURES STR',
#  'marketName': 'DBMF',
#  'minTick': 0.01,
#  'orderTypes': 'ACTIVETIM,AD,ADDONT,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,BENCHPX,CASHQTY,COND,CONDORDER,DARKONLY,DARKPOLL,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,DUR,GAT,GTC,GTD,GTT,HID,IBKRATS,ICE,IOC,LIT,LMT,LOC,MIDPX,MIT,MKT,MOC,MTL,NGCOMB,NODARK,NONALGO,OCA,OPG,OPGREROUT,PEGBENCH,PEGMID,POSTATS,POSTONLY,PREOPGRTH,PRICECHK,REL,REL2MID,RELPCTOFS,RTH,SCALE,SCALEODD,SCALERST,SIZECHK,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,SWEEP,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF',
#  'priceMagnifier': 1,
#  'primaryExchange': 'ARCA',
#  'secType': 'STK',
#  'subcategory': '',
#  'symbol': 'DBMF',
#  'tradingHours': '20260329:CLOSED;20260330:0400-20260330:2000;20260331:0400-20260331:2000;20260401:0400-20260401:2000;20260402:0400-20260402:2000',
#  'validExchanges': 'SMART,AMEX,NYSE,CBOE,PHLX,ISE,CHX,ARCA,ISLAND,DRCTEDGE,BEX,BATS,EDGEA,BYX,IEX,EDGX,FOXRIVER,PEARL,NYSENAT,LTSE,MEMX,IBEOS,OVERNIGHT,TPLUS0,PSX,T24X'}

# %%
try:
    client.connect()
    security_info = client.require_security_info(
        symbol="DBMF",
        sec_type=SEC_TYPE,
        exchange=EXCHANGE,
        primary_exchange="SBF",
        currency=CURRENCY,
        conid=CONID,
        local_symbol=LOCAL_SYMBOL,
    )
finally:
    client.disconnect()

pprint(security_info)
# Out:
# {'category': '',
#  'conId': 774094650,
#  'currency': 'USD',
#  'exchange': 'SMART',
#  'industry': '',
#  'liquidHours': '20260329:CLOSED;20260330:0900-20260330:1730;20260331:0900-20260331:1730;20260401:0900-20260401:1730;20260402:0900-20260402:1730',
#  'localSymbol': 'DBMF',
#  'longName': 'IMGP DBI MNG FUT FD RU UE-RU',
#  'marketName': 'DBMF',
#  'minTick': 0.01,
#  'orderTypes': 'ACTIVETIM,AD,ADJUST,ALERT,ALGOLTH,ALLOC,AVGCOST,BASKET,BENCHPX,CASHQTY,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,IOC,LIT,LMT,LOC,LTH,MIT,MKT,MKT2BBO,MOC,MTL,NGCOMB,NODARK,NONALGO,OCA,OPG,PEGBENCH,REL,RELPCTOFS,SIZECHK,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF',
#  'priceMagnifier': 1,
#  'primaryExchange': 'SBF',
#  'secType': 'STK',
#  'subcategory': '',
#  'symbol': 'DBMF',
#  'tradingHours': '20260329:CLOSED;20260330:0900-20260330:1740;20260331:0900-20260331:1740;20260401:0900-20260401:1740;20260402:0900-20260402:1740',
#  'validExchanges': 'SMART,SBF,LSEETF,TRWBUKETF'}
